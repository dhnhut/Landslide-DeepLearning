# %% [markdown]
# # Data Processing

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# # Load data

# %%
directory = 'data/NZ_landslide_inventory/'
geo_filepath = f'{directory}/raw_data.gpkg'
gdf = gpd.read_file(geo_filepath, layer='landslides')
gdf.head()
# Out:
#    OBJECTID  landslide_point_type landslide_point_description  \
# 0         1  Centre of Evacuation                        None
# 1         2  Centre of Evacuation                        None
# 2         3  Centre of Evacuation                        None
# 3         4  Centre of Evacuation                        None
# 4         5  Centre of Evacuation                        None
#
#                    Landslide_GUID_point  \
# 0  714143f7-4ae2-ed11-8847-00224818a32c
# 1  67def7c6-4de2-ed11-8847-00224818ad3f
# 2  b012b8df-46e2-ed11-8847-00224818a32c
# 3  fe1e4a15-b7e3-ed11-8847-00224818ad3f
# 4  043c5354-c2e3-ed11-8847-00224818a32c
#
#                                                 name activitytype  \
# 0  South-eastern end of Blockhouse Bay Beach Reserve         None
# 1                                    Gittos Domain A         None
# 2                           Arch Hill Scenic Reserve         None
# 3                           Rotary Reserve, Te Atahu         None
# 4                               Telephone Rd Reserve         None
#
#    areamaximum                                        description  \
# 0          NaN  Slip debris blocks public path and extends ove...
# 1          NaN  Minor landslide/scouring has occurred on north...
# 2          NaN  Landslip undermined part of concrete walkway &...
# 3          NaN  Landslide has occurred on eastern side of exis...
# 4          NaN  Slip scarp head undercutting stairs + deck at ...
#
#   isvalidlandslide sourcedescription  ... widthrupture     xcoordinate  \
# 0              Yes  Auckland Council  ...         19.0  1,751,568.9990
# 1              Yes  Auckland Council  ...          4.0  1,751,927.3675
# 2              Yes  Auckland Council  ...         12.0  1,754,943.6098
# 3              Yes  Auckland Council  ...          6.0  1,747,554.2439
# 4              Yes  Auckland Council  ...          5.0  1,754,134.7853
#
#       ycoordinate        dateoccurence recentdateoccurrence  \
# 0  5,911,395.1893  2023-02-13 23:00:00                 None
# 1  5,912,169.8622  2023-01-30 23:00:00                 None
# 2  5,918,430.2890  2023-01-31 23:00:00                 None
# 3  5,919,202.5713  2023-02-13 23:00:00                 None
# 4  5,923,952.9585  2023-01-31 23:00:00                 None
#
#             modifiedon originaldatabaseid  primarymovementtypesubclass  \
# 0  2024-12-04 20:38:18               None                         None
# 1  2024-12-04 20:38:18               None                         None
# 2  2024-12-04 20:38:18               None                         None
# 3  2024-12-04 20:38:18               None                         None
# 4  2024-12-04 20:38:18               None                         None
#
#                                GlobalID                     geometry
# 0  cb20f8d7-abeb-4ce5-bafa-a75c01b03136  POINT (174.70188 -36.93131)
# 1  9da581bc-ff20-454f-b6fb-721279cd347a  POINT (174.70575 -36.92427)
# 2  2a361da4-7adf-4f4d-b94c-f3cf9ccccc46  POINT (174.73832 -36.86737)
# 3  4470b30b-6c80-46be-b0f7-e4ec0a5d72fd   POINT (174.6553 -36.86159)
# 4  cfcff56a-7cc6-41f5-9e7e-8da0daa5dbde  POINT (174.72813 -36.81774)
#
# [5 rows x 92 columns]

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 146813 entries, 0 to 146812
# Data columns (total 92 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   OBJECTID                     146813 non-null  int64
#  1   landslide_point_type         146813 non-null  object
#  2   landslide_point_description  23 non-null      object
#  3   Landslide_GUID_point         146813 non-null  object
#  4   name                         146806 non-null  object
#  5   activitytype                 146621 non-null  object
#  6   areamaximum                  146789 non-null  float64
#  7   description                  66 non-null      object
#  8   isvalidlandslide             146813 non-null  object
#  9   sourcedescription            146809 non-null  object
#  10  parentid_value               0 non-null       object
#  11  parentid_name                0 non-null       object
#  12  primarymovementid_value      146799 non-null  object
#  13  createdon                    146813 non-null  object
#  14  accumulation                 48 non-null      object
#  15  activityrecent               154 non-null     object
#  16  activityvelocity             51 non-null      object
#  17  anglerupturesurface          29 non-null      float64
#  18  angleslopedisplaced          45 non-null      float64
#  19  angleslopeprior              56 non-null      float64
#  20  areamethod                   42 non-null      object
#  21  areaminimum                  43 non-null      float64
#  22  aspect                       64 non-null      object
#  23  causeprimary                 157 non-null     object
#  24  causesecondary               37 non-null      object
#  25  comments                     106 non-null     object
#  26  damageassets                 48 non-null      object
#  27  damagecost_base              17 non-null      object
#  28  damagecost                   17 non-null      object
#  29  damagedeaths                 45 non-null      float64
#  30  damagedescription            64 non-null      object
#  31  damageenvironmental          47 non-null      object
#  32  damageinjuries               46 non-null      float64
#  33  dateconfidence               50 non-null      object
#  34  datingmethodaccuracy         130 non-null     object
#  35  deaths                       10 non-null      object
#  36  depletion                    55 non-null      float64
#  37  depthrupture                 56 non-null      float64
#  38  disabled                     146813 non-null  object
#  39  geology                      69 non-null      object
#  40  geometrymodifiedon           34 non-null      object
#  41  geomorphology                55 non-null      object
#  42  howfind                      53 non-null      object
#  43  howserious                   50 non-null      object
#  44  impactedfeatures             52 non-null      object
#  45  injuries                     10 non-null      object
#  46  isduplicatelandslide         146813 non-null  object
#  47  ispublic                     146813 non-null  object
#  48  latitude                     146812 non-null  float64
#  49  longitude                    146812 non-null  float64
#  50  length                       48 non-null      float64
#  51  locationaccuracy             149 non-null     object
#  52  locationaccuracygns          0 non-null       object
#  53  locationdescription          165 non-null     object
#  54  materialdebristype           154 non-null     object
#  55  materialtype                 146807 non-null  object
#  56  method                       164 non-null     object
#  57  movement                     61 non-null      object
#  58  movementstyle                146 non-null     object
#  59  numberofslips                138 non-null     object
#  60  physicalsetting              165 non-null     object
#  61  primarymovement              97 non-null      object
#  62  projectid                    24 non-null      object
#  63  qalevel                      35 non-null      object
#  64  qastatus                     35 non-null      object
#  65  recentmovement               37 non-null      object
#  66  region                       146812 non-null  object
#  67  scarp                        58 non-null      float64
#  68  secondarymovement            31 non-null      object
#  69  sizeofslip                   9 non-null       object
#  70  sourcebulkupload             146750 non-null  object
#  71  sourcetype                   146795 non-null  object
#  72  travelangle                  25 non-null      float64
#  73  triggerearthquake            6 non-null       float64
#  74  triggerrainfall1day          44 non-null      float64
#  75  triggerrainfall3day          49 non-null      float64
#  76  triggerrainfall7day          34 non-null      float64
#  77  upslopecatchmentdescription  24 non-null      object
#  78  vegetation                   160 non-null     object
#  79  volumemaximum                43 non-null      object
#  80  volumeminimum                42 non-null      float64
#  81  width                        52 non-null      float64
#  82  widthrupture                 63 non-null      float64
#  83  xcoordinate                  146812 non-null  object
#  84  ycoordinate                  146812 non-null  object
#  85  dateoccurence                194 non-null     object
#  86  recentdateoccurrence         133 non-null     object
#  87  modifiedon                   146813 non-null  object
#  88  originaldatabaseid           0 non-null       object
#  89  primarymovementtypesubclass  48 non-null      object
#  90  GlobalID                     146813 non-null  object
#  91  geometry                     146813 non-null  geometry
# dtypes: float64(21), geometry(1), int64(1), object(69)
# memory usage: 103.0+ MB

# %% [markdown]
# ## Columns Selection

# %%
gdf = gdf[
    ['GlobalID', 'geometry', 'latitude', 'longitude', 'region', 'dateoccurence', 'dateconfidence', 'geometrymodifiedon','createdon']
]

# %% [markdown]
# ## Feature Processing

# %%
display(gdf.info())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 146813 entries, 0 to 146812
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   GlobalID            146813 non-null  object
#  1   geometry            146813 non-null  geometry
#  2   latitude            146812 non-null  float64
#  3   longitude           146812 non-null  float64
#  4   region              146812 non-null  object
#  5   dateoccurence       194 non-null     object
#  6   dateconfidence      50 non-null      object
#  7   geometrymodifiedon  34 non-null      object
#  8   createdon           146813 non-null  object
# dtypes: float64(2), geometry(1), object(6)
# memory usage: 10.1+ MB
# None

# %% [markdown]
# ### Closest date of occurence

# %%
gdf[['dateoccurence', 'createdon', 'dateconfidence', 'geometrymodifiedon']]
# Out:
#               dateoccurence            createdon             dateconfidence  \
# 0       2023-02-13 23:00:00  2023-04-24 02:51:58  2023-03-16T12:00:00+13:00
# 1       2023-01-30 23:00:00  2023-04-24 03:12:02                       None
# 2       2023-01-31 23:00:00  2023-04-24 02:22:43                       None
# 3       2023-02-13 23:00:00  2023-04-25 22:18:23                       None
# 4       2023-01-31 23:00:00  2023-04-25 23:38:50                       None
# ...                     ...                  ...                        ...
# 146808  2023-01-27 11:00:00  2024-08-06 21:50:12  2023-01-27T21:00:00+13:00
# 146809  1900-01-01 00:00:00  2023-11-03 02:57:09                       None
# 146810  2009-09-30 00:00:00  2024-03-04 22:33:57  2023-02-06T12:00:00+13:00
# 146811  2023-01-26 11:00:00  2024-11-12 00:44:16  2023-01-27T12:00:00+13:00
# 146812  2023-01-26 11:00:00  2024-07-18 03:30:33  2024-04-19T11:00:00+12:00
#
#         geometrymodifiedon
# 0        4/26/2023 2:11 AM
# 1        4/24/2023 3:16 AM
# 2        4/25/2023 9:21 PM
# 3       4/25/2023 10:21 PM
# 4       4/25/2023 11:41 PM
# ...                    ...
# 146808                None
# 146809                None
# 146810                None
# 146811                None
# 146812                None
#
# [146813 rows x 4 columns]

# %%
# Convert columns to datetime
for col in [
    'dateoccurence', 'dateconfidence', 'createdon', 'geometrymodifiedon'
    ]:
    # Convert invalid values to NaT and use GMT timezone
    gdf[col] = pd.to_datetime(gdf[col], errors='coerce', utc=True)
    gdf[col] = gdf[col].dt.tz_localize(None)  #

# %% [markdown]
# Check if timezone make change in date

# %%
gdf[
    gdf['dateconfidence'].notna() &
    (gdf['dateconfidence'] < gdf['dateoccurence'])]
[['dateconfidence','dateoccurence']]
# Out:
# [['dateconfidence', 'dateoccurence']]

# %%
gdf['closestdate'] = gdf[
    ['dateoccurence', 'createdon', 'dateconfidence', 'geometrymodifiedon']
    ].min(axis=1)

# %%
gdf.drop(
    columns=['createdon', 'dateconfidence', 'geometrymodifiedon']
    , inplace=True)

# %%
gdf.drop(gdf[gdf['closestdate']<'2022-01-01'].index, inplace=True)

# %%
gdf.head()
# Out:
#                                GlobalID                     geometry  \
# 0  cb20f8d7-abeb-4ce5-bafa-a75c01b03136  POINT (174.70188 -36.93131)
# 1  9da581bc-ff20-454f-b6fb-721279cd347a  POINT (174.70575 -36.92427)
# 2  2a361da4-7adf-4f4d-b94c-f3cf9ccccc46  POINT (174.73832 -36.86737)
# 3  4470b30b-6c80-46be-b0f7-e4ec0a5d72fd   POINT (174.6553 -36.86159)
# 4  cfcff56a-7cc6-41f5-9e7e-8da0daa5dbde  POINT (174.72813 -36.81774)
#
#     latitude   longitude           region       dateoccurence  \
# 0 -36.931306  174.701880  Auckland Region 2023-02-13 23:00:00
# 1 -36.924269  174.705747  Auckland Region 2023-01-30 23:00:00
# 2 -36.867368  174.738318  Auckland Region 2023-01-31 23:00:00
# 3 -36.861593  174.655298  Auckland Region 2023-02-13 23:00:00
# 4 -36.817738  174.728127  Auckland Region 2023-01-31 23:00:00
#
#           closestdate
# 0 2023-02-13 23:00:00
# 1 2023-01-30 23:00:00
# 2 2023-01-31 23:00:00
# 3 2023-02-13 23:00:00
# 4 2023-01-31 23:00:00

# %% [markdown]
# ### Areas

# %%
gdf['region'].value_counts()
# Out:
# region
# Hawke's Bay Region           104221
# Gisborne Region               26895
# Auckland Region               11916
# Manawatu-Whanganui Region      3530
# Waikato Region                  167
# Northland Region                 44
# Bay of Plenty Region              5
# Name: count, dtype: int64

# %% [markdown]
# ### Export Cleanned data

# %%
gdf[gdf['region']=='Auckland Region'].to_file(
    f'{directory}/cleaned_auckland.gpkg', driver='GPKG', layer='landslides')

gdf[gdf['region']!='Auckland Region'].to_file(
    f'{directory}/cleaned_non_auckland.gpkg', driver='GPKG', layer='landslides')
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/geo/lib/python3.13/site-packages/pyogrio/geopandas.py:710: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   write(
# /opt/homebrew/Caskroom/miniconda/base/envs/geo/lib/python3.13/site-packages/pyogrio/geopandas.py:710: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   write(
