# %% [markdown]
# # Data Processing

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# # Load data

# %%
directory = 'data/NZ_landslide_inventory/'
geo_filepath = f'{directory}/raw_data.gpkg'
gdf = gpd.read_file(geo_filepath, layer='landslides')
gdf.head()
# Out:
#    OBJECTID  landslide_point_type landslide_point_description  \
# 0         1  Centre of Evacuation                        None
# 1         2  Centre of Evacuation                        None
# 2         3  Centre of Evacuation                        None
# 3         4  Centre of Evacuation                        None
# 4         5  Centre of Evacuation                        None
#
#                    Landslide_GUID_point  \
# 0  714143f7-4ae2-ed11-8847-00224818a32c
# 1  67def7c6-4de2-ed11-8847-00224818ad3f
# 2  b012b8df-46e2-ed11-8847-00224818a32c
# 3  fe1e4a15-b7e3-ed11-8847-00224818ad3f
# 4  043c5354-c2e3-ed11-8847-00224818a32c
#
#                                                 name activitytype  \
# 0  South-eastern end of Blockhouse Bay Beach Reserve         None
# 1                                    Gittos Domain A         None
# 2                           Arch Hill Scenic Reserve         None
# 3                           Rotary Reserve, Te Atahu         None
# 4                               Telephone Rd Reserve         None
#
#    areamaximum                                        description  \
# 0          NaN  Slip debris blocks public path and extends ove...
# 1          NaN  Minor landslide/scouring has occurred on north...
# 2          NaN  Landslip undermined part of concrete walkway &...
# 3          NaN  Landslide has occurred on eastern side of exis...
# 4          NaN  Slip scarp head undercutting stairs + deck at ...
#
#   isvalidlandslide sourcedescription  ...           modifiedon  \
# 0              Yes  Auckland Council  ...  2024-12-04 20:38:18
# 1              Yes  Auckland Council  ...  2024-12-04 20:38:18
# 2              Yes  Auckland Council  ...  2024-12-04 20:38:18
# 3              Yes  Auckland Council  ...  2024-12-04 20:38:18
# 4              Yes  Auckland Council  ...  2024-12-04 20:38:18
#
#   originaldatabaseid primarymovementtypesubclass  \
# 0               None                        None
# 1               None                        None
# 2               None                        None
# 3               None                        None
# 4               None                        None
#
#                             landslideid              createdby createdbyemail  \
# 0  714143f7-4ae2-ed11-8847-00224818a32c  Iris@aosullivan.co.nz           None
# 1  67def7c6-4de2-ed11-8847-00224818ad3f  Iris@aosullivan.co.nz           None
# 2  b012b8df-46e2-ed11-8847-00224818a32c  Iris@aosullivan.co.nz           None
# 3  fe1e4a15-b7e3-ed11-8847-00224818ad3f  Iris@aosullivan.co.nz           None
# 4  043c5354-c2e3-ed11-8847-00224818a32c  Iris@aosullivan.co.nz           None
#
#                           landslideguid               modifiedby  \
# 0  714143f7-4ae2-ed11-8847-00224818a32c  Thomas.Greenop@beca.com
# 1  67def7c6-4de2-ed11-8847-00224818ad3f  Thomas.Greenop@beca.com
# 2  b012b8df-46e2-ed11-8847-00224818a32c    Iris@aosullivan.co.nz
# 3  fe1e4a15-b7e3-ed11-8847-00224818ad3f    Iris@aosullivan.co.nz
# 4  043c5354-c2e3-ed11-8847-00224818a32c  Thomas.Greenop@beca.com
#
#                                  GlobalID                     geometry
# 0  {4CBA5CA3-25B2-4C2B-90A9-56AA245B7D34}  POINT (174.70188 -36.93131)
# 1  {E4E31F12-8A45-4ABE-B466-0177413FE603}  POINT (174.70575 -36.92427)
# 2  {5ED9073C-1CAA-4A1A-93C8-525FC913809F}  POINT (174.73832 -36.86737)
# 3  {B1435F74-BAE8-4549-B8F5-7AA6A203CC46}   POINT (174.6553 -36.86159)
# 4  {AF544C9E-0A5D-4A35-91A2-AECC8449A096}  POINT (174.72813 -36.81774)
#
# [5 rows x 97 columns]

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 154397 entries, 0 to 154396
# Data columns (total 97 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   OBJECTID                     154397 non-null  int64
#  1   landslide_point_type         154397 non-null  object
#  2   landslide_point_description  348 non-null     object
#  3   Landslide_GUID_point         154397 non-null  object
#  4   name                         154372 non-null  object
#  5   activitytype                 153775 non-null  object
#  6   areamaximum                  152097 non-null  float64
#  7   description                  511 non-null     object
#  8   isvalidlandslide             154397 non-null  object
#  9   sourcedescription            154371 non-null  object
#  10  parentid_value               2 non-null       object
#  11  parentid_name                1 non-null       object
#  12  primarymovementid_value      151941 non-null  object
#  13  createdon                    154397 non-null  object
#  14  accumulation                 212 non-null     object
#  15  activityrecent               2513 non-null    object
#  16  activityvelocity             207 non-null     object
#  17  anglerupturesurface          137 non-null     float64
#  18  angleslopedisplaced          198 non-null     float64
#  19  angleslopeprior              241 non-null     float64
#  20  areamethod                   362 non-null     object
#  21  areaminimum                  157 non-null     float64
#  22  aspect                       256 non-null     object
#  23  causeprimary                 154333 non-null  object
#  24  causesecondary               162 non-null     object
#  25  comments                     2315 non-null    object
#  26  damageassets                 192 non-null     object
#  27  damagecost_base              44 non-null      object
#  28  damagecost                   44 non-null      object
#  29  damagedeaths                 459 non-null     float64
#  30  damagedescription            260 non-null     object
#  31  damageenvironmental          169 non-null     object
#  32  damageinjuries               219 non-null     float64
#  33  dateconfidence               192 non-null     object
#  34  datingmethodaccuracy         2584 non-null    object
#  35  deaths                       29 non-null      object
#  36  depletion                    234 non-null     float64
#  37  depthrupture                 218 non-null     float64
#  38  disabled                     154397 non-null  object
#  39  geology                      497 non-null     object
#  40  geometrymodifiedon           124 non-null     object
#  41  geomorphology                223 non-null     object
#  42  howfind                      216 non-null     object
#  43  howserious                   189 non-null     object
#  44  impactedfeatures             200 non-null     object
#  45  injuries                     29 non-null      object
#  46  isduplicatelandslide         154397 non-null  object
#  47  ispublic                     154397 non-null  object
#  48  latitude                     154101 non-null  float64
#  49  longitude                    154101 non-null  float64
#  50  length                       198 non-null     float64
#  51  locationaccuracy             2741 non-null    object
#  52  locationaccuracygns          0 non-null       object
#  53  locationdescription          2548 non-null    object
#  54  materialdebristype           2510 non-null    object
#  55  materialtype                 154139 non-null  object
#  56  method                       154342 non-null  object
#  57  movement                     154365 non-null  object
#  58  movementstyle                2733 non-null    object
#  59  numberofslips                196 non-null     object
#  60  physicalsetting              2545 non-null    object
#  61  primarymovement              2534 non-null    object
#  62  projectid                    154233 non-null  object
#  63  qalevel                      2677 non-null    object
#  64  qastatus                     95 non-null      object
#  65  recentmovement               127 non-null     object
#  66  region                       154101 non-null  object
#  67  scarp                        254 non-null     float64
#  68  secondarymovement            360 non-null     object
#  69  sizeofslip                   29 non-null      object
#  70  sourcebulkupload             154152 non-null  object
#  71  sourcetype                   154333 non-null  object
#  72  travelangle                  103 non-null     float64
#  73  triggerearthquake            20 non-null      float64
#  74  triggerrainfall1day          446 non-null     float64
#  75  triggerrainfall3day          168 non-null     float64
#  76  triggerrainfall7day          131 non-null     float64
#  77  upslopecatchmentdescription  92 non-null      object
#  78  vegetation                   2534 non-null    object
#  79  volumemaximum                164 non-null     object
#  80  volumeminimum                163 non-null     float64
#  81  width                        202 non-null     float64
#  82  widthrupture                 252 non-null     float64
#  83  xcoordinate                  154132 non-null  object
#  84  ycoordinate                  154132 non-null  object
#  85  dateoccurence                154397 non-null  object
#  86  recentdateoccurrence         2660 non-null    object
#  87  modifiedon                   154397 non-null  object
#  88  originaldatabaseid           0 non-null       object
#  89  primarymovementtypesubclass  0 non-null       object
#  90  landslideid                  154397 non-null  object
#  91  createdby                    486 non-null     object
#  92  createdbyemail               17 non-null      object
#  93  landslideguid                154397 non-null  object
#  94  modifiedby                   154397 non-null  object
#  95  GlobalID                     154397 non-null  object
#  96  geometry                     154396 non-null  geometry
# dtypes: float64(21), geometry(1), int64(1), object(74)
# memory usage: 114.3+ MB

# %% [markdown]
# ## Columns Selection

# %%
gdf = gdf[
    ['GlobalID', 'geometry', 'latitude', 'longitude', 'region', 'dateoccurence', 'dateconfidence', 'geometrymodifiedon','createdon']
]

# %% [markdown]
# ## Feature Processing

# %%
display(gdf.info())
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 154397 entries, 0 to 154396
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   GlobalID            154397 non-null  object
#  1   geometry            154396 non-null  geometry
#  2   latitude            154101 non-null  float64
#  3   longitude           154101 non-null  float64
#  4   region              154101 non-null  object
#  5   dateoccurence       154397 non-null  object
#  6   dateconfidence      192 non-null     object
#  7   geometrymodifiedon  124 non-null     object
#  8   createdon           154397 non-null  object
# dtypes: float64(2), geometry(1), object(6)
# memory usage: 10.6+ MB
# None

# %% [markdown]
# ### Closest date of occurence

# %%
gdf[['dateoccurence', 'createdon', 'dateconfidence', 'geometrymodifiedon']]
# Out:
#               dateoccurence            createdon             dateconfidence  \
# 0       2023-02-13 23:00:00  2023-04-24 02:51:58  2023-03-16T12:00:00+13:00
# 1       2023-01-30 23:00:00  2023-04-24 03:12:02                       None
# 2       2023-01-31 23:00:00  2023-04-24 02:22:43                       None
# 3       2023-02-13 23:00:00  2023-04-25 22:18:23                       None
# 4       2023-01-31 23:00:00  2023-04-25 23:38:50                       None
# ...                     ...                  ...                        ...
# 154392  2023-02-10 11:00:00  2024-06-11 03:22:09  2023-02-06T12:00:00+13:00
# 154393  2013-10-01 00:00:00  2024-01-25 02:50:58  2023-01-27T12:00:00+13:00
# 154394  2013-10-01 00:00:00  2024-01-25 02:50:58  2023-01-27T12:00:00+13:00
# 154395  2013-10-01 00:00:00  2024-01-25 02:50:58  2023-01-27T12:00:00+13:00
# 154396  2023-01-26 11:00:00  2024-04-08 01:47:24  2023-01-27T12:00:00+13:00
#
#         geometrymodifiedon
# 0        4/26/2023 2:11 AM
# 1        4/24/2023 3:16 AM
# 2        4/25/2023 9:21 PM
# 3       4/25/2023 10:21 PM
# 4       4/25/2023 11:41 PM
# ...                    ...
# 154392                None
# 154393                None
# 154394                None
# 154395                None
# 154396    4/8/2024 3:18 AM
#
# [154397 rows x 4 columns]

# %%
# Convert columns to datetime
# for col in [
#     'dateoccurence', 'dateconfidence', 'createdon', 'geometrymodifiedon'
#     ]:
for col in ['dateoccurence']:
    # Convert invalid values to NaT and use GMT timezone
    gdf[col] = pd.to_datetime(gdf[col], errors='coerce', utc=True)
    gdf[col] = gdf[col].dt.tz_localize(None)  #

# %% [markdown]
# Check if timezone make change in date

# %%
# gdf[
#     gdf['dateconfidence'].notna() &
#     (gdf['dateconfidence'] < gdf['dateoccurence'])]
# [['dateconfidence','dateoccurence']]

# %%
# gdf['closestdate'] = gdf[
#     ['dateoccurence', 'createdon', 'dateconfidence', 'geometrymodifiedon']
#     ].min(axis=1)

# %%
# gdf.drop(
#     columns=['createdon', 'dateconfidence', 'geometrymodifiedon']
#     , inplace=True)

# %%
# Data error
# gdf.drop(gdf[gdf['closestdate']<'2022-01-01'].index, inplace=True)
gdf.drop(gdf[gdf['dateoccurence']<'2022-01-01'].index, inplace=True)

# %%
# group by month and year count number of landslides
landslide_counts = gdf.copy()
landslide_counts['year_month'] = landslide_counts['dateoccurence'].dt.to_period('M')
landslide_counts = landslide_counts.groupby('year_month').size().reset_index(name='counts')

landslide_counts
# Out:
#   year_month  counts
# 0    2022-07       2
# 1    2022-11       2
# 2    2023-01    2765
# 3    2023-02  151588
# 4    2023-08       5
# 5    2024-01       5
# 6    2025-01       1

# %%
gdf.head()
# Out:
#                                  GlobalID                     geometry  \
# 0  {4CBA5CA3-25B2-4C2B-90A9-56AA245B7D34}  POINT (174.70188 -36.93131)
# 1  {E4E31F12-8A45-4ABE-B466-0177413FE603}  POINT (174.70575 -36.92427)
# 2  {5ED9073C-1CAA-4A1A-93C8-525FC913809F}  POINT (174.73832 -36.86737)
# 3  {B1435F74-BAE8-4549-B8F5-7AA6A203CC46}   POINT (174.6553 -36.86159)
# 4  {AF544C9E-0A5D-4A35-91A2-AECC8449A096}  POINT (174.72813 -36.81774)
#
#     latitude   longitude           region        dateoccurence  \
# 0 -36.931306  174.701880  Auckland Region  2023-02-13 23:00:00
# 1 -36.924269  174.705747  Auckland Region  2023-01-30 23:00:00
# 2 -36.867368  174.738318  Auckland Region  2023-01-31 23:00:00
# 3 -36.861593  174.655298  Auckland Region  2023-02-13 23:00:00
# 4 -36.817738  174.728127  Auckland Region  2023-01-31 23:00:00
#
#               dateconfidence  geometrymodifiedon            createdon
# 0  2023-03-16T12:00:00+13:00   4/26/2023 2:11 AM  2023-04-24 02:51:58
# 1                       None   4/24/2023 3:16 AM  2023-04-24 03:12:02
# 2                       None   4/25/2023 9:21 PM  2023-04-24 02:22:43
# 3                       None  4/25/2023 10:21 PM  2023-04-25 22:18:23
# 4                       None  4/25/2023 11:41 PM  2023-04-25 23:38:50

# %% [markdown]
# ### Areas

# %%
gdf['region'].value_counts()
# Out:
# region
# Hawke's Bay Region           106330
# Gisborne Region               28356
# Auckland Region               15644
# Manawatu-Whanganui Region      3530
# Waikato Region                  167
# Northland Region                 44
# Bay of Plenty Region              5
# Name: count, dtype: int64

# %% [markdown]
# ### Export Cleanned data

# %%
gdf[gdf['region']=='Auckland Region'].to_file(
    f'{directory}/cleaned_auckland.gpkg', driver='GPKG', layer='landslides')

gdf[gdf['region']!='Auckland Region'].to_file(
    f'{directory}/cleaned_non_auckland.gpkg', driver='GPKG', layer='landslides')
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/geo/lib/python3.12/site-packages/pyogrio/geopandas.py:710: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   write(
# /opt/homebrew/Caskroom/miniconda/base/envs/geo/lib/python3.12/site-packages/pyogrio/geopandas.py:710: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   write(
