# %% [markdown]
# # Fetch Auckland Landslide Inventory

# %%
import os
import pandas as pd
import geopandas as gpd

from libs.auckland_landslide_inventory import fetch_data, layers

# %%
out_dir = 'data/NZ_landslide_inventory'
# fetch_data(out_dir, num_records=2, batch_size=1)
fetch_data(out_dir)
# Out:
# Fetching records 0 to 2000 for layer points...
# /opt/homebrew/Caskroom/miniconda/base/envs/geo/lib/python3.12/site-packages/pyogrio/geopandas.py:710: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   write(
# /opt/homebrew/Caskroom/miniconda/base/envs/geo/lib/python3.12/site-packages/pyogrio/geopandas.py:710: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   write(
# Fetching records 2000 to 4000 for layer points...
# /opt/homebrew/Caskroom/miniconda/base/envs/geo/lib/python3.12/site-packages/pyogrio/geopandas.py:710: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   write(
# ...

# %%
for layer_name in layers().keys():
    print(f"Reading layer: {layer_name}")
    gdf = gpd.read_file(out_dir + "/inventory.gpkg", layer=layer_name)
    display(gdf.head())
# Out:
# Reading layer: points
#                                GlobalID  \
# 0  ba3029d3-d716-4493-8bd6-88c5befc7b02
# 1  93831bdc-182f-4ef0-ac4e-4398bb5ff5e6
# 2  9c5ebd1c-fcf3-4e55-b25c-ed0db13c3dec
# 3  6cf2181c-9feb-4a03-8d43-f0f7796cc8b2
# 4  5f347692-b75b-4503-b692-b0f26ed5c3c8
#
#                                   sourcebibliography rainfalldescription  \
# 0  Ex Tropical Cyclone Gabrielle (12-16 February ...                None
# 1  Ex Tropical Cyclone Gabrielle (12-16 February ...                None
# 2  Ex Tropical Cyclone Gabrielle (12-16 February ...                None
# 3  Ex Tropical Cyclone Gabrielle (12-16 February ...                None
# 4  Ex Tropical Cyclone Gabrielle (12-16 February ...                None
#
#    OBJECTID  landslide_point_type landslide_point_description  \
# 0        48  Centre of Evacuation                        None
# 1       272  Centre of Evacuation                        None
# 2       389  Centre of Evacuation                        None
# ...
