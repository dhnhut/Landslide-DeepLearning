# %% [markdown]
# # Landslide Susceptibility Map of North Carolina

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data explorer

# %%
df_landslides = pd.read_csv('data/landslides.csv')
df_non_landslides = pd.read_csv('data/non-landslides.csv')

# %%
df_landslides.head()
# Out:
#        Slope  Elevation     Aspect          PL           PR  V          TWI  \
# 0    36.1675    5011.34   344.7780   -17.22330    10.191700  1     8.281640
# 1    36.5210    4554.55   160.3770    13.94120   -13.198800  1     0.300393
# 2    23.7662    4409.65    32.7448    -2.84497    -0.729969  1     2.429630
# 3 -9999.0000   -9999.00 -9999.0000 -9999.00000 -9999.000000  1 -9999.000000
# 4    26.3401    3703.81   141.0570    -7.56331     8.946680  1     4.136980
#
#           SPI          TRI
# 0  2466.80000     0.534318
# 1     0.87064     0.448263
# 2     2.24412     0.562683
# 3 -9999.00000 -9999.000000
# 4    15.94360     0.535470

# %%
df_landslides.head()
# Out:
#        Slope  Elevation     Aspect          PL           PR  V          TWI  \
# 0    36.1675    5011.34   344.7780   -17.22330    10.191700  1     8.281640
# 1    36.5210    4554.55   160.3770    13.94120   -13.198800  1     0.300393
# 2    23.7662    4409.65    32.7448    -2.84497    -0.729969  1     2.429630
# 3 -9999.0000   -9999.00 -9999.0000 -9999.00000 -9999.000000  1 -9999.000000
# 4    26.3401    3703.81   141.0570    -7.56331     8.946680  1     4.136980
#
#           SPI          TRI
# 0  2466.80000     0.534318
# 1     0.87064     0.448263
# 2     2.24412     0.562683
# 3 -9999.00000 -9999.000000
# 4    15.94360     0.535470
